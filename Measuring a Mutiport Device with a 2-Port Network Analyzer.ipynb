# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook demonstrates numerical test of the technique described in
# "*A Rigorous Technique for Measuring the Scattering Matrix of a Multiport Device with a 2-Port Network Analyzer*" [1].
#
# In microwave measurements,  once commonly needs to measure a n-port deveice  with a m-port network analyzer ($ m<n $ duh!). Generally, this is done by  terminating each non-measured port with a matched load, and assuming the reflected power is negligable. In some cases this may not provide the most accurate results, or even be possible in all measurement environments. The paper above presents an elegent solution to this problem. We'll call it *Tippet's* technique, because it has a good right to it.
#
# In Tippets technique, the sub-networks are measured in a similar way as before, but the port terminations are not assume to be matched. Instead, the terminations have to be known, and not neccesarily having a low reflection. Each port is terminated with a consistent termination. So port 1 is always terminated with $Z_1$ when not being measured. Once measured, each sub-network is re-normalized to these port impedances. Finally the composit network is contructed, and  may then be re-normalized to the desired system impedance, say $50 ohm $
#
#
#
# * [1] J. C. Tippet and R. A. Speciale, “A Rigorous Technique for Measuring the Scattering Matrix of a Multiport Device with a 2-Port Network Analyzer,” IEEE Transactions on Microwave Theory and Techniques, vol. 30, no. 5, pp. 661–666, May 1982.

# %% [markdown]
# ## Outline of Tippet's Technique

# %% [markdown]
# Following the example given in [1], (they measure a 4-port network with a 2-port network analyzer.)
#
# An outline of the technique:
#
# 1. Calibrate 2-port network analyzer
# 2. Get four known terminations ($Z_1, Z_2, Z_3,Z_4$). No more than one can have  $|\Gamma| = 1$
# 3. Measure all combinations of 2-port subnetworks (there are 6). Each port not currently being measured must be terminated with its corresponding load.
# 4. Renormalize each subnetwork to the impedances of the loads used to terminate it when note being measured.
# 5. Build composite 4-port, renormalize to VNA impedance.

# %% [markdown]
# # Implementation

# %%
import skrf as rf 
from itertools import combinations

# %% [markdown]
# First, we create a Media object, which is used to generate networks for testing. We will use WR-10 Rectangular waveguide.

# %%
wg = rf.wr10
wg.frequency.npoints = 101

# %% [markdown]
# Next, lets generate a random 4-port network which will be the DUT, that we are trying to measure with out 2-port network analyzer.

# %%
dut = wg.random(n_ports  = 4,name= 'dut')
dut
# Out:
# 4-Port Network: 'dut',  75-110 GHz, 101 pts, z0=[ 50.+0.j  50.+0.j  50.+0.j  50.+0.j]

# %% [markdown]
# Now, we need to define the loads used to terminate each port when it is not being measured, note as described in [1] not more than one can be have full reflection, $|\Gamma| = 1$

# %%
loads = [wg.load(.1+.1j),
         wg.load(.2-.2j),
         wg.load(.3+.3j),
         wg.load(.5),
         ]
# construct the impedance array, of shape FXN
z_loads = array([k.z.flatten() for k in loads]).T

# %% [markdown]
# Create measurement combinations, here are 6 different measurements required for a

# %%
ports = arange(four_port.nports)
port_combos = list(combinations(ports, 2))
port_combos
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# %% [markdown]
# Now to do it. Ok we loop over the port combo's and connect the loads to the right places, simulating  actual measurements. Each subnetwork measurement is saved, along with the renormalized subnetwork.   Finally, we stuff the result into the 4-port composit network.

# %%
composite = wg.match(nports = 4)  # composite network, to be filled.
measured,measured_renorm = {},{}  # measured subnetworks and renormalized sub-networks


# ports  `a` and `b` are the ports we will connect the VNA too
for a,b in port_combos:
    # port `c` and `d` are the ports which we will connect the loads too
    c,d =ports[(ports!=a)& (ports!=b)] 
    
    # determine where `d` will be on four_port, after its reduced to a three_port
    e = where(ports[ports!=c]==d)[0][0]

    # connect loads
    three_port = rf.connect(four_port,c, loads[c],0)
    two_port =  rf.connect(three_port,e, loads[d],0)
    
    # save raw and renormalized 2-port subnetworks
    measured['%i%i'%(a,b)] = two_port.copy()
    two_port.renormalize(c_[z_loads[:,a],z_loads[:,b]])
    measured_renorm['%i%i'%(a,b)] = two_port.copy()
    
    # stuff this 2-port into the composite 4-port 
    for i,m in enumerate([a,b]):
        for j,n in enumerate([a,b]):
            composite.s[:,m,n] = two_port.s[:,i,j]
    
    # properly copy the port impedances
    composite.z0[:,a] = two_port.z0[:,0]
    composite.z0[:,b] = two_port.z0[:,1]
    

# finally renormalize from 
composite.renormalize(50)

# %% [markdown]
# Note that 6-measurements of 2-port subnetworks works out to 24-sparameters, and we only need 16. This is because each reflect, s-parameter is measured three-times. We will use this redundent measurement as a check of our accuracy.

# %%
measured_renorm
# Out:
# {'01': 2-Port Network: '',  75-110 GHz, 101 pts, z0=[ 59.75609756+12.19512195j  67.64705882-29.41176471j],
#  '02': 2-Port Network: '',  75-110 GHz, 101 pts, z0=[ 59.75609756+12.19512195j  70.68965517+51.72413793j],
#  '03': 2-Port Network: '',  75-110 GHz, 101 pts, z0=[  59.75609756+12.19512195j  150.00000000 +0.j        ],
#  '12': 2-Port Network: '',  75-110 GHz, 101 pts, z0=[ 67.64705882-29.41176471j  70.68965517+51.72413793j],
#  '13': 2-Port Network: '',  75-110 GHz, 101 pts, z0=[  67.64705882-29.41176471j  150.00000000 +0.j        ],
#  '23': 2-Port Network: '',  75-110 GHz, 101 pts, z0=[  70.68965517+51.72413793j  150.00000000 +0.j        ]}

# %%
rf.NS([measured[k] for k in measured if k[0]=='0']).plot_s_db(0,0)
# Out:
# [None, None, None]

# %%
rf.NS([measured_renorm[k] for k in measured_renorm if k[0]=='0']).plot_s_db(0,0)
# Out:
# [None, None, None]

# %%
composite == four_port
# Out:
# True

# %%
sum((composite - four_port).s_mag)
# Out:
# 9.3741520808639742e-13
